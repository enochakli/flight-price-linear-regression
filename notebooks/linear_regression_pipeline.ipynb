# %% [markdown]
# <a href="https://colab.research.google.com/github/enochakli/flight-price-linear-regression/blob/main/notebooks/linear_regression_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
